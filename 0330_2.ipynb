# %% [markdown]
# <a href="https://colab.research.google.com/github/caiyu-yang/Bigdata/blob/main/0330_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("rJava")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("jiebaR")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("tmcn")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("dplyr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("lubridate")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("stringr")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("wordcloud")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("wordcloud2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
install.packages("Rwordseg", repos = "http://R-Forge.R-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “dependency ‘HMM’ is not available”
# Warning message in install.packages("Rwordseg", repos = "http://R-Forge.R-project.org"):
# “installation of package ‘Rwordseg’ had non-zero exit status”

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
library(lubridate)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union

# %%
library(stringr)

# %%
library(jiebaR)
# Out:
# Loading required package: jiebaRD

# %%
library(wordcloud)
# Out:
# Loading required package: RColorBrewer

# %%
library(wordcloud2)

# %%
content <- "中國駐英國使館關於涉疆問題的聲明1月12日，英國外交發展大臣拉布等在英國議會下院就中國新疆事務大放厥詞，污衊和抹黑新疆發展和中國涉疆政策，妄稱將就所謂新疆“強制勞動”問題對有關公司採取限制措施，藉口涉疆問題粗暴干涉中國內政。中方對此表示強烈不滿和堅決反對。一段時間以來，英國等西方國家大肆捏造和傳播所謂新疆“大規模拘禁”、“壓製文化”、“強制絕育”、“強迫勞動”等“世紀謊言”。中方通過多雙邊渠道，多次向英方及有關國家介紹情況、澄清事實、揭批謬論、闡明立場。中方迄已發布8本涉疆白皮書，新疆維吾爾自治區政府舉辦了22場新聞發布會，介紹新疆經濟社會發展狀況和有關事實真相。近年來，中方還邀請了來自100多個國家的1000多名外交官、記者和宗教團體代表參訪新疆，實地了解真實情況。2020年10月19日至22日，20個阿拉伯國家及阿盟駐華使節和外交官參訪了新疆，積極評價新疆經濟社會和人權事業發展成就，指出外界關於中國和新疆人權狀況的謊言毫無根據。但令人遺憾和憤慨的是，英方固持偏見、罔顧事實，在涉疆問題上顛倒黑白、混淆視聽，採取各種消極措施。中方對此堅決反對，並願重申以下嚴正立場：第一，當前新疆維吾爾自治區社會穩定、經濟增長、民族團結、宗教和睦、文化發展、民生改善，這是有目共睹、不容否認的基本事實。各種涉疆謠言謊言純屬無稽之談，主要是由一些西方國家反華勢力和不良機構、媒體蓄意炮製和擴散。比如，2010年至2018年，新疆維吾爾族人口從1017萬上升至1272萬，增加255萬，增幅為25%，大約是全疆人口增幅14%的兩倍，更明顯高於漢族人口增幅2% ，所謂“強制絕育”簡直荒唐。再如，鄭國恩等反華分子僅僅通過對8名維吾爾人的採訪和粗略估算，就得出所謂“新疆2000多萬人口中，10%的人被拘押在'再教育營'”的荒謬結論。在事實和真相面前，這些虛假信息和荒謬言論不攻自破。第二，根本不存在所謂新疆“強迫勞動”問題。幫助新疆各族群眾實現穩定就業與“強迫勞動”完全是兩個概念。新疆各族勞動者根據自己的意願選擇就業，本著平等自願原則與企業依法簽訂《勞動合同》；各級政府充分尊重各族群眾就業意願，並為自願報名的勞動者提高就業技能提供必要培訓。《新疆少數民族勞動就業調查報告》顯示，被調查的4個村村民自願外出就業意願平均值高達86.5％，表明少數民族群眾自願外出就業意願十分強烈。新疆各族群眾勞動脫貧致富後的笑臉是對有關謊言謠言的最好和最有力回應。第三，新疆事務純屬中國內政，絕不容任何外國以任何方式乾涉。英方有關舉措不斷違背國際關係基本準則，也違反國際貿易規則、市場經濟原則，破壞全球產業鏈、供應鏈，將損害包括英國在內的各國企業和消費者利益，是典型的損人不利己行為。中方一貫反對將經貿問題政治化，將依法採取必要舉措，維護中方合法權益。我們強烈敦促英方摒棄偏見、尊重事實，立即撤銷錯誤決定，立即停止炒作涉疆“世紀謊言”，立即停止干涉中國內政，不要在錯誤的道路上越走越遠，否則只能搬起石頭砸自己的腳。"

#  [58] "對此"             "表示"             "強烈不滿"
# ...

# %%
new_words <- c("中國內政","新疆問題","強制絕育","強迫勞動","涉疆白皮書","新疆人權","壓製文化","大規模拘禁","再教育營","提高就業技能","提供必要培訓","新聞發布會")
for(i in 1:length(new_words)){
  new_user_word(cutter, new_words[i])
}

# %%
content <- str_remove_all(content, "[0-9a-zA-Z]+?")
cutter[content]
# Out:
#   [1] "中國"             "駐"               "英國"
#   [4] "使館"             "關於"             "涉疆"
#   [7] "問題"             "聲明"             "月"
#  [10] "日"               "英國"             "外交"
#  [13] "發展"             "大臣"             "拉布"
#  [16] "等"               "英國議會"         "下院"
#  [19] "中國"             "新疆"             "事務"
#  [22] "大放厥詞"         "污衊"             "抹黑"
#  [25] "新疆"             "發展"             "中國"
#  [28] "涉疆"             "政策"             "妄稱"
#  [31] "將就"             "所謂"             "新疆"
#  [34] "強制"             "勞動"             "問題"
#  [37] "有關"             "公司"             "採取"
#  [40] "限制"             "措施"             "藉口"
#  [43] "涉疆"             "問題"             "粗暴"
#  [46] "干涉"             "中國內政"         "中方"
#  [49] "對此"             "表示"             "強烈不滿"
#  [52] "堅決"             "反對"             "一段時間"
#  [55] "以來"             "英國"             "等"
#  [58] "西方"             "國家"             "大肆"
#  [61] "捏造"             "傳播"             "所謂"
# ...

# %%
new_words <- c("中國內政","強制絕育","強迫勞動","涉疆白皮書","新疆人權","壓製文化","大規模拘禁","再教育營","提高就業技能","提供必要培訓","新聞發布會")
writeLines(new_words, "new_words.txt")

# %%
stop_words <- c("在","之","更","個","未","而","也","與","的","和","是","及","了","對","上","年","就","將","至","被","所謂")
writeLines(stop_words, "stop_words.txt")

# %%
cutter <- worker(user = "new_words.txt", stop_word = "stop_words.txt",
bylines = FALSE)

# %%
seg_words <- cutter[content]
seg_words
# Out:
#   [1] "中國"             "駐"               "英國"
#   [4] "使館"             "關於"             "涉疆"
#   [7] "問題"             "聲明"             "月"
#  [10] "日"               "英國"             "外交"
#  [13] "發展"             "大臣"             "拉布"
#  [16] "等"               "英國議會"         "下院"
#  [19] "中國"             "新疆"             "事務"
#  [22] "大放厥詞"         "污衊"             "抹黑"
#  [25] "新疆"             "發展"             "中國"
#  [28] "涉疆"             "政策"             "妄稱"
#  [31] "將就"             "新疆"             "強制"
#  [34] "勞動"             "問題"             "有關"
#  [37] "公司"             "採取"             "限制"
#  [40] "措施"             "藉口"             "涉疆"
#  [43] "問題"             "粗暴"             "干涉"
#  [46] "中國內政"         "中方"             "對此"
#  [49] "表示"             "強烈不滿"         "堅決"
#  [52] "反對"             "一段時間"         "以來"
#  [55] "英國"             "等"               "西方"
#  [58] "國家"             "大肆"             "捏造"
#  [61] "傳播"             "新疆"             "大規模拘禁"
# ...

# %%
txt_freq <- freq(seg_words)

# %%
txt_freq <- arrange(txt_freq, desc(freq))

# %%
head(txt_freq)
# Out:
#   char freq
# 1 新疆 16
# 2 中方  7
# 3 問題  6
# 4 涉疆  6
# 5 就業  5
# 6 謊言  5

# %%
par(family=("Microsoft YaHei"))

# %%
wordcloud(txt_freq$char, txt_freq$freq, min.freq = 2, random.order = F,
ordered.colors = F, colors = rainbow(nrow(txt_freq)))
# Out:
# plot without title

# %%
install.packages("showtext")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(showtext)
# Out:
# Loading required package: sysfonts
#
# Loading required package: showtextdb

# %%
showtext.auto(enable = TRUE)
# Out:
# 'showtext.auto()' is now renamed to 'showtext_auto()'
# The old version still works, but consider using the new function in future code
